# %%
import pandas as pd
list_ = ["This is my first NLP exercise", "omg!!!!!"]
series_data = pd.Series(list_, name='text')


list_ = ["This is my first NLP exercise", "omg!!!!!"]

# Lowercase
list_lower = [text.lower() for text in list_]
print("List Lowercase:", list_lower)

# Uppercase
list_upper = [text.upper() for text in list_]
print("List Uppercase:", list_upper)
# Out:
# List Lowercase: ['this is my first nlp exercise', 'omg!!!!!']
# List Uppercase: ['THIS IS MY FIRST NLP EXERCISE', 'OMG!!!!!']
