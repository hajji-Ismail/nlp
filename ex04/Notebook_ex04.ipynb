# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt_tab')

text = """
The goal of this exercise is to learn to remove stop words with NLTK.  Stop words usually refer to the most common words in a language.
"""
stop_words = set(stopwords.words('english'))


tokens = word_tokenize(text)

filtered_sentence = [w for w in tokens if w.lower() not in stop_words]

print(filtered_sentence)
# Out:
# ['goal', 'exercise', 'learn', 'remove', 'stop', 'words', 'NLTK', '.', 'Stop', 'words', 'usually', 'refer', 'common', 'words', 'language', '.']
# [nltk_data] Downloading package stopwords to /home/ihajji/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/ihajji/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
